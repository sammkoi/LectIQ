# %%
import pandas as pd
import re

# %%
all_sheets = pd.read_excel("galectins_id.xlsx", sheet_name=None)
data = {}
for glectin in all_sheets:
  temp = all_sheets[glectin]
  data[glectin] = temp[temp["Glycan"].notna()].reset_index(drop=True)
  data[glectin] = data[glectin].drop(columns=['Symbol'])

# %%
with pd.ExcelWriter("galectins_id_cleaned.xlsx") as writer:
  for glectin, df in data.items():
    df.to_excel(writer, sheet_name=glectin, index=False)

# %%
with pd.ExcelWriter("output.xlsx") as writer:
  for glectin in data:
    df = data[glectin]
    df.to_excel(writer, sheet_name=re.sub(r'[\\/*?:[\]]', '_', glectin), index=False)
# Out:
# dict

# %%
temp = data['hGal-1']

# %%
temp
# Out:
#      ID                                             Glycan  Symbol        Kd  \
# 0    L1  β-D-Gal-(1→4)-β-D-GlcNAc(1→3)-β-D-Gal(1→4)-β-D...     NaN  0.454545
# 1    L2  α-D-Neu5Ac(2→3)-β-D-Gal(1→3)-[α-L-Fuc(1→4)]-β-...     NaN  3.333333
# 2    L3  α-L-Fuc(1→2)-β-D-Gal(1→3)-β-D-GlcNAc(1→3)-β-D-...     NaN  1.428571
# 3    L4  β-D-Gal(1→3)-[α-L-Fuc(1→4)]-β-D-GlcNAc(1→3)-β-...     NaN  2.500000
# 4    L5  β-D-Gal-(1→4)-β-D-GlcNAc-(1→3)-β-D-Gal-(1→4)-β...     NaN  0.769231
# 5    L6  β-D-Gal(1→4)-β-D-GlcNAc(1→3)-β-D-Gal(1→4)-β-D-...     NaN  0.833333
# 6    L7  β-D-Gal-(1→4)-[α-L-Fuc-(1→3)]-β-D-GlcNAc-(1→3)...     NaN  1.428571
# 7    L8  β-D-Gal(1→4)-β-D-GlcNAc(1→6)-[-β-D-Gal(1→4)-β-...     NaN  0.333333
# 8    L9  β-D-Gal(1→3)-β-D-GlcNAc(1→3)-β-D-Gal(1→4)-β-D-Glc     NaN  0.188679
# 9   L10  β-D-Gal-(1→4)-[α-L-Fuc-(1→3)]-β-D-GlcNAc-(1→6)...     NaN  0.833333
# 10  L11  α-D-Neu5Ac(2→3)-β-D-Gal(1→3)-β-D-GlcNAc(1→3)-β...     NaN  0.500000
# ...

# %%
import requests
from bs4 import BeautifulSoup

# url = "https://image.glycosmos.org/snfg/png/G70000DB"
# url = "https://api.glygen.org/glycan/image/G70000DB"
url = "https://api.glygen.org/glycan/image_svg/G17689DH/"

# %%
response = requests.get(url)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 response = requests.get(url)
#
# File ~/Projects/chemdb/.venv/lib/python3.13/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/Projects/chemdb/.venv/lib/python3.13/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
# ...

# %%
byte_str = response.contents

# %%
import io
from PIL import Image

# %%
img = Image.open(io.BytesIO(byte_str))

img.show()
